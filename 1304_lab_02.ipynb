# %% [markdown]
# <a href="https://colab.research.google.com/github/poojitha-unnam/PDS-1304-/blob/main/1304_lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 QUESTION

# %%
import numpy as np
import matplotlib.pyplot as plt
monthly_temps_c = np.array([7.5, 12.0, 16.4, 20.1, 24.5, 27.0, 26.5, 22.0, 16.0, 10.2, 6.1])
avg_temp = np.mean(monthly_temps_c)
hottest_month = np.argmax(monthly_temps_c) + 1
coldest_month = np.argmin(monthly_temps_c) + 1
normalized_temps = (monthly_temps_c - monthly_temps_c.min()) / (monthly_temps_c.max() - monthly_temps_c.min())
above_avg_months = np.where(monthly_temps_c > avg_temp)[0] + 1
temps_fahrenheit = monthly_temps_c * 9/5 + 32
months = range(1, len(monthly_temps_c) + 1)
plt.plot(months, monthly_temps_c, marker='+', label='Celsius')
plt.plot(months, temps_fahrenheit, marker='_', label='Fahrenheit', linestyle='--')
plt.title("Monthly Temperature")
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Monthly Temperatures (°C):", monthly_temps_c)
print("Average Temperature (°C):", round(avg_temp, 2))
print("Hottest Month:", hottest_month)
print("Coldest Month:", coldest_month)
print("Normalized Temperatures:", np.round(normalized_temps, 2))
print("Above Average Months:", above_avg_months)
print("Temperatures in Fahrenheit (°F):", np.round(temps_fahrenheit, 2))
# Out:
# Monthly Temperatures (°C): [ 7.5 12.  16.4 20.1 24.5 27.  26.5 22.  16.  10.2  6.1]
# Average Temperature (°C): 17.12
# Hottest Month: 6
# Coldest Month: 11
# Normalized Temperatures: [0.07 0.28 0.49 0.67 0.88 1.   0.98 0.76 0.47 0.2  0.  ]
# Above Average Months: [4 5 6 7 8]
# Temperatures in Fahrenheit (°F): [45.5  53.6  61.52 68.18 76.1  80.6  79.7  71.6  60.8  50.36 42.98]

# %% [markdown]
# #2 QUESTION

# %%
import pandas as pd
data = {
'Order ID': [101, 102, 103, 104, 105, 106, 107],
'Product': ['Laptop', 'Phone', 'Tablet', 'Laptop', 'Headphones', 'Phone', 'Tablet'],
'Quantity': [1, 2, 3, 1, 5, 2, 4],
'Price': [1200, 600, 300, 1300, 100, 650, 280]
}
df = pd.DataFrame(data)
df['Total Sale'] = df['Quantity'] * df['Price']
high_value_orders = df[df['Total Sale'] > 1000]
product_sales = df.groupby('Product')['Quantity'].sum()
most_sold_product = product_sales.idxmax()
df['Discount'] = df['Total Sale'].apply(lambda x: x * 0.10 if x > 1000 else x * 0.05)
df.to_excel('sales_summary.xlsx', index=False)
print("Full DataFrame:\n", df)
print("\n High Value Orders (> $1000):\n", high_value_orders)
print("\n Most Sold Product:", most_sold_product)
# Out:
# Full DataFrame:
#     Order ID     Product  Quantity  Price  Total Sale  Discount
# 0       101      Laptop         1   1200        1200     120.0
# 1       102       Phone         2    600        1200     120.0
# 2       103      Tablet         3    300         900      45.0
# 3       104      Laptop         1   1300        1300     130.0
# 4       105  Headphones         5    100         500      25.0
# 5       106       Phone         2    650        1300     130.0
# 6       107      Tablet         4    280        1120     112.0
#
#  High Value Orders (> $1000):
#     Order ID Product  Quantity  Price  Total Sale
# 0       101  Laptop         1   1200        1200
# 1       102   Phone         2    600        1200
# 3       104  Laptop         1   1300        1300
# 5       106   Phone         2    650        1300
# 6       107  Tablet         4    280        1120
#
#  Most Sold Product: Tablet
